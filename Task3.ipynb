# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Covid.data')

# %%
data
# Out:
#        # Country,\nOther Total\nCases Total\nDeaths  New\nDeaths  \
# 0      1             USA   98,166,904     1,084,282          NaN
# 1      2           India   44,587,307       528,629          NaN
# 2      3          France   35,342,950       155,078          NaN
# 3      4          Brazil   34,706,757       686,027          NaN
# 4      5         Germany   33,312,373       149,948          NaN
# ..   ...             ...          ...           ...          ...
# 225  226            Niue           80           NaN          NaN
# 226  227    Vatican City           29           NaN          NaN
# 227  228          Tuvalu           20           NaN          NaN
# 228  229  Western Sahara           10             1          NaN
# 229  230      MS Zaandam            9             2          NaN
#
#     Total\nRecovered Active\nCases Serious,\nCritical Tot Cases/\n1M pop  \
# 0         94,962,112     2,120,510              2,970            293,206
# ...

# %%
data.head()
# Out:
#    # Country,\nOther Total\nCases Total\nDeaths  New\nDeaths Total\nRecovered  \
# 0  1             USA   98,166,904     1,084,282          NaN       94,962,112
# 1  2           India   44,587,307       528,629          NaN       44,019,095
# 2  3          France   35,342,950       155,078          NaN       34,527,115
# 3  4          Brazil   34,706,757       686,027          NaN       33,838,636
# 4  5         Germany   33,312,373       149,948          NaN       32,315,200
#
#   Active\nCases Serious,\nCritical Tot Cases/\n1M pop Deaths/\n1M pop  \
# 0     2,120,510              2,970            293,206           3,239
# 1        39,583                698             31,698             376
# 2       660,757                869            538,892           2,365
# 3       182,094              8,318            161,162           3,186
# 4       847,225              1,406            397,126           1,788
#
#     Total\nTests Tests/\n1M pop     Population
# ...

# %%
data.head(2)
# Out:
#    # Country,\nOther Total\nCases Total\nDeaths  New\nDeaths Total\nRecovered  \
# 0  1             USA   98,166,904     1,084,282          NaN       94,962,112
# 1  2           India   44,587,307       528,629          NaN       44,019,095
#
#   Active\nCases Serious,\nCritical Tot Cases/\n1M pop Deaths/\n1M pop  \
# 0     2,120,510              2,970            293,206           3,239
# 1        39,583                698             31,698             376
#
#     Total\nTests Tests/\n1M pop     Population
# 0  1,118,158,870      3,339,729    334,805,269
# 1    894,416,853        635,857  1,406,631,776

# %%
data.tail(2)
# Out:
#        # Country,\nOther Total\nCases Total\nDeaths  New\nDeaths  \
# 228  229  Western Sahara           10             1          NaN
# 229  230      MS Zaandam            9             2          NaN
#
#     Total\nRecovered Active\nCases Serious,\nCritical Tot Cases/\n1M pop  \
# 228                9             0                NaN                 16
# 229                7             0                NaN                NaN
#
#     Deaths/\n1M pop Total\nTests Tests/\n1M pop Population
# 228               2          NaN            NaN    626,161
# 229             NaN          NaN            NaN        NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230 entries, 0 to 229
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   #                  230 non-null    int64
#  1   Country,
# Other     230 non-null    object
#  2   Total
# Cases        230 non-null    object
#  3   Total
# Deaths       225 non-null    object
#  4   New
# Deaths         3 non-null      float64
#  5   Total
# Recovered    214 non-null    object
#  6   Active
# Cases       215 non-null    object
#  7   Serious,
# Critical  147 non-null    object
#  8   Tot Cases/
# 1M pop  228 non-null    object
#  9   Deaths/
# 1M pop     223 non-null    object
#  10  Total
# Tests        214 non-null    object
#  11  Tests/
# 1M pop      214 non-null    object
#  12  Population         228 non-null    object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 23.5+ KB

# %%
data.shape
# Out:
# (230, 13)

# %%
data.columns
# Out:
# Index(['#', 'Country,\nOther', 'Total\nCases', 'Total\nDeaths', 'New\nDeaths',
#        'Total\nRecovered', 'Active\nCases', 'Serious,\nCritical',
#        'Tot Cases/\n1M pop', 'Deaths/\n1M pop', 'Total\nTests',
#        'Tests/\n1M pop', 'Population'],
#       dtype='object')

# %%
import numpy as np 

data.replace("?",np.nan,inplace = True)
data.head(7)
# Out:
#    # Country,\nOther Total\nCases Total\nDeaths  New\nDeaths Total\nRecovered  \
# 0  1             USA   98,166,904     1,084,282          NaN       94,962,112
# 1  2           India   44,587,307       528,629          NaN       44,019,095
# 2  3          France   35,342,950       155,078          NaN       34,527,115
# 3  4          Brazil   34,706,757       686,027          NaN       33,838,636
# 4  5         Germany   33,312,373       149,948          NaN       32,315,200
# 5  6        S. Korea   24,769,101        28,406         42.0       24,013,461
# 6  7              UK   23,621,952       189,919          NaN       23,347,871
#
#   Active\nCases Serious,\nCritical Tot Cases/\n1M pop Deaths/\n1M pop  \
# 0     2,120,510              2,970            293,206           3,239
# 1        39,583                698             31,698             376
# 2       660,757                869            538,892           2,365
# ...

# %%
print(data.isnull().sum())
# Out:
# #                       0
# Country,\nOther         0
# Total\nCases            0
# Total\nDeaths           5
# New\nDeaths           227
# Total\nRecovered       16
# Active\nCases          15
# Serious,\nCritical     83
# Tot Cases/\n1M pop      2
# Deaths/\n1M pop         7
# Total\nTests           16
# Tests/\n1M pop         16
# Population              2
# dtype: int64

# %%
X = data.iloc[: , :-1].values

y = data.iloc[: , :3].valuse

# %%
X
# Out:
# array([[1, 'USA', '98,166,904', ..., '3,239', '1,118,158,870',
#         '3,339,729'],
#        [2, 'India', '44,587,307', ..., '376', '894,416,853', '635,857'],
#        [3, 'France', '35,342,950', ..., '2,365', '271,490,188',
#         '4,139,547'],
#        ...,
#        [228, 'Tuvalu', '20', ..., nan, nan, nan],
#        [229, 'Western Sahara', '10', ..., '2', nan, nan],
#        [230, 'MS Zaandam', '9', ..., nan, nan, nan]], dtype=object)

# %%
data.dtypes
# Out:
# #                       int64
# Country,\nOther        object
# Total\nCases           object
# Total\nDeaths          object
# New\nDeaths           float64
# Total\nRecovered       object
# Active\nCases          object
# Serious,\nCritical     object
# Tot Cases/\n1M pop     object
# Deaths/\n1M pop        object
# Total\nTests           object
# Tests/\n1M pop         object
# Population             object
# dtype: object

# %%
data['Country,\nOther']=data['Country,\nOther'].astype(int)

# %%
data
# Out:
#        # Country,\nOther Total\nCases Total\nDeaths  New\nDeaths  \
# 0      1             USA   98,166,904     1,084,282          NaN
# 1      2           India   44,587,307       528,629          NaN
# 2      3          France   35,342,950       155,078          NaN
# 3      4          Brazil   34,706,757       686,027          NaN
# 4      5         Germany   33,312,373       149,948          NaN
# ..   ...             ...          ...           ...          ...
# 225  226            Niue           80           NaN          NaN
# 226  227    Vatican City           29           NaN          NaN
# 227  228          Tuvalu           20           NaN          NaN
# 228  229  Western Sahara           10             1          NaN
# 229  230      MS Zaandam            9             2          NaN
#
#     Total\nRecovered Active\nCases Serious,\nCritical Tot Cases/\n1M pop  \
# 0         94,962,112     2,120,510              2,970            293,206
# ...

# %%
data['Country,\nOther']=data['Country,\nOther'].str.replace(',','').astype(int)

# %%
data
# Out:
#        # Country,\nOther Total\nCases Total\nDeaths  New\nDeaths  \
# 0      1             USA   98,166,904     1,084,282          NaN
# 1      2           India   44,587,307       528,629          NaN
# 2      3          France   35,342,950       155,078          NaN
# 3      4          Brazil   34,706,757       686,027          NaN
# 4      5         Germany   33,312,373       149,948          NaN
# ..   ...             ...          ...           ...          ...
# 225  226            Niue           80           NaN          NaN
# 226  227    Vatican City           29           NaN          NaN
# 227  228          Tuvalu           20           NaN          NaN
# 228  229  Western Sahara           10             1          NaN
# 229  230      MS Zaandam            9             2          NaN
#
#     Total\nRecovered Active\nCases Serious,\nCritical Tot Cases/\n1M pop  \
# 0         94,962,112     2,120,510              2,970            293,206
# ...

# %%
data.fillna({"Total\nDeaths":"Not Available", "New\nDeaths": -1})
# Out:
#        # Country,\nOther Total\nCases  Total\nDeaths  New\nDeaths  \
# 0      1             USA   98,166,904      1,084,282         -1.0
# 1      2           India   44,587,307        528,629         -1.0
# 2      3          France   35,342,950        155,078         -1.0
# 3      4          Brazil   34,706,757        686,027         -1.0
# 4      5         Germany   33,312,373        149,948         -1.0
# ..   ...             ...          ...            ...          ...
# 225  226            Niue           80  Not Available         -1.0
# 226  227    Vatican City           29  Not Available         -1.0
# 227  228          Tuvalu           20  Not Available         -1.0
# 228  229  Western Sahara           10              1         -1.0
# 229  230      MS Zaandam            9              2         -1.0
#
#     Total\nRecovered Active\nCases Serious,\nCritical Tot Cases/\n1M pop  \
# 0         94,962,112     2,120,510              2,970            293,206
# ...

# %%
data.drop(['Total\nCases','Active\nCases'], axis=1)
# Out:
#        # Country,\nOther Total\nDeaths  New\nDeaths Total\nRecovered  \
# 0      1             USA     1,084,282          NaN       94,962,112
# 1      2           India       528,629          NaN       44,019,095
# 2      3          France       155,078          NaN       34,527,115
# 3      4          Brazil       686,027          NaN       33,838,636
# 4      5         Germany       149,948          NaN       32,315,200
# ..   ...             ...           ...          ...              ...
# 225  226            Niue           NaN          NaN               80
# 226  227    Vatican City           NaN          NaN               29
# 227  228          Tuvalu           NaN          NaN              NaN
# 228  229  Western Sahara             1          NaN                9
# 229  230      MS Zaandam             2          NaN                7
#
#     Serious,\nCritical Tot Cases/\n1M pop Deaths/\n1M pop   Total\nTests  \
# ...

# %%
data['New\nDeaths'].isna().sum()
# Out:
# 227

# %%
data['New\nDeaths'].fillna.(0, inplace=True)

# %%
data['New\nDeaths'] =data['New\nDeaths'].fillna(0)

# %%
data['New\nDeaths']
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 225   NaN
# 226   NaN
# 227   NaN
# 228   NaN
# 229   NaN
# Name: New\nDeaths, Length: 230, dtype: float64
